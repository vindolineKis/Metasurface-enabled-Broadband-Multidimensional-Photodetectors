# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2024-04-30 22:44:36.742182: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 22:44:36.791900: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 22:44:36.791949: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 22:44:36.793671: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 22:44:36.802001: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 22:44:36.802960: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 22:44:38.746601: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# 载入数据
file_path = 'Dataset_new.xlsx'
data = pd.read_excel(file_path)

# %%
print(data.columns)
# Out:
# Index(['x1', 'x2', 'x3', 'wlt', 'wave_half_f', 'wave_half', 'wave_01',
#        'wavelength', 'spin', 'Unnamed: 9', 'range', 'label'],
#       dtype='object')

# %%
# 特征和标签
X = data[['x1', 'x2', 'x3']].values
# y_spin = data[['y1', 'y2', 'y3']].values
y_spin = data[['spin']].values
y_wavelength = to_categorical(data['wave_half'].values, num_classes=14)

# %%
# 拆分数据集
X_train, X_test, y_spin_train, y_spin_test, y_wavelength_train, y_wavelength_test = train_test_split(
    X, y_spin, y_wavelength, test_size=0.3, random_state=42)# stratify=y_wavelength.argmax(axis=1)


# nn model
input_layer = Input(shape=(X.shape[1],))
hidden_layer_1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(input_layer)
bn1 = BatchNormalization()(hidden_layer_1)
drop_out_1 = Dropout(0.3)(bn1)  # 调整Dropout比率
hidden_layer_2 = Dense(256, activation='relu')(drop_out_1)
bn2 = BatchNormalization()(hidden_layer_2)
drop_out_2 = Dropout(0.3)(bn2)
hidden_layer_3 = Dense(64, activation='relu')(drop_out_2)
bn3 = BatchNormalization()(hidden_layer_3)
drop_out_3 = Dropout(0.3)(bn3)
hidden_layer_4 = Dense(128, activation='relu')(drop_out_3)
bn4 = BatchNormalization()(hidden_layer_4)
hidden_layer_5 = Dense(256, activation='relu')(hidden_layer_1)
# bn5 = BatchNormalization()(hidden_layer_5)
hidden_layer_6 = Dense(512, activation='relu')(hidden_layer_5)
# bn6 = BatchNormalization()(hidden_layer_6)
# hidden_layer_7 = Dense(256, activation='relu')(hidden_layer_6)
# bn7 = BatchNormalization()(hidden_layer_7)
hidden_layer_8 = Dense(128, activation='relu')(hidden_layer_6)
bn8 = BatchNormalization()(hidden_layer_8)
# hidden_layer_9 = Dense(64, activation='relu')(hidden_layer_8)
# bn9 = BatchNormalization()(hidden_layer_9)
hidden_layer_10 = Dense(32, activation='relu')(hidden_layer_8)
bn10 = BatchNormalization()(hidden_layer_10)


# 输出层，确保两个输出连接到同一层
spin_output = Dense(1, activation='sigmoid', name='spin_output', kernel_regularizer=l2(0.001))(hidden_layer_4)
wavelength_output = Dense(y_wavelength.shape[1], activation='softmax', name='wavelength_output', kernel_regularizer=l2(0.001))(bn10)

# %%
# 创建模型
model = Model(inputs=input_layer, outputs=[spin_output, wavelength_output])

# 损失函数：前三个输出用二元交叉熵，最后一个输出用分类交叉熵
losses = {
    'spin_output': 'binary_crossentropy',
    'wavelength_output': 'categorical_crossentropy'
}

# 编译模型
model.compile(optimizer=Adam(), loss=losses, metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# 训练模型
model.fit(X_train, [y_spin_train, y_wavelength_train], 
          validation_data=(X_test, [y_spin_test, y_wavelength_test]), 
          epochs=100, 
          batch_size=32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 82ms/step - loss: 0.7272 - spin_output_loss: 0.1292 - wavelength_output_loss: 0.5549 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8367 - val_loss: 2.1388 - val_spin_output_loss: 0.1589 - val_wavelength_output_loss: 1.9368 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 2/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6543 - spin_output_loss: 0.1583 - wavelength_output_loss: 0.4529 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.8878 - val_loss: 1.9942 - val_spin_output_loss: 0.1532 - val_wavelength_output_loss: 1.7980 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 3/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.6028 - spin_output_loss: 0.1737 - wavelength_output_loss: 0.3861 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.8776 - val_loss: 1.9625 - val_spin_output_loss: 0.1597 - val_wavelength_output_loss: 1.7598 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 4/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.4435 - spin_output_loss: 0.0988 - wavelength_output_loss: 0.3017 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8980 - val_loss: 1.9321 - val_spin_output_loss: 0.1601 - val_wavelength_output_loss: 1.7290 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 5/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4867 - spin_output_loss: 0.1542 - wavelength_output_loss: 0.2895 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.9286 - val_loss: 1.9229 - val_spin_output_loss: 0.1664 - val_wavelength_output_loss: 1.7135 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 6/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4111 - spin_output_loss: 0.1377 - wavelength_output_loss: 0.2304 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9082 - val_loss: 1.8921 - val_spin_output_loss: 0.1695 - val_wavelength_output_loss: 1.6796 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 7/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.4137 - spin_output_loss: 0.1850 - wavelength_output_loss: 0.1857 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 1.8421 - val_spin_output_loss: 0.1735 - val_wavelength_output_loss: 1.6256 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6905
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3723 - spin_output_loss: 0.1471 - wavelength_output_loss: 0.1822 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 1.8203 - val_spin_output_loss: 0.1882 - val_wavelength_output_loss: 1.5891 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7143
# Epoch 9/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.4009 - spin_output_loss: 0.1776 - wavelength_output_loss: 0.1802 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 1.8402 - val_spin_output_loss: 0.1895 - val_wavelength_output_loss: 1.6077 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 10/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.3407 - spin_output_loss: 0.1270 - wavelength_output_loss: 0.1706 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9490 - val_loss: 1.8624 - val_spin_output_loss: 0.1888 - val_wavelength_output_loss: 1.6305 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 11/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3655 - spin_output_loss: 0.1357 - wavelength_output_loss: 0.1867 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 1.7786 - val_spin_output_loss: 0.1981 - val_wavelength_output_loss: 1.5374 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7143
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4157 - spin_output_loss: 0.1459 - wavelength_output_loss: 0.2267 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9388 - val_loss: 1.7418 - val_spin_output_loss: 0.2002 - val_wavelength_output_loss: 1.4985 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.7381
# Epoch 13/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.3769 - spin_output_loss: 0.1358 - wavelength_output_loss: 0.1979 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9388 - val_loss: 1.7073 - val_spin_output_loss: 0.1927 - val_wavelength_output_loss: 1.4714 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.7381
# Epoch 14/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4261 - spin_output_loss: 0.2111 - wavelength_output_loss: 0.1718 - spin_output_accuracy: 0.8980 - wavelength_output_accuracy: 0.9694 - val_loss: 1.6592 - val_spin_output_loss: 0.1836 - val_wavelength_output_loss: 1.4324 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7619
# Epoch 15/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3647 - spin_output_loss: 0.1616 - wavelength_output_loss: 0.1600 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9694 - val_loss: 1.6166 - val_spin_output_loss: 0.1862 - val_wavelength_output_loss: 1.3872 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7143
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3044 - spin_output_loss: 0.1053 - wavelength_output_loss: 0.1559 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9796 - val_loss: 1.5854 - val_spin_output_loss: 0.1797 - val_wavelength_output_loss: 1.3625 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7143
# Epoch 17/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3281 - spin_output_loss: 0.1367 - wavelength_output_loss: 0.1482 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9796 - val_loss: 1.5827 - val_spin_output_loss: 0.1823 - val_wavelength_output_loss: 1.3572 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7381
# Epoch 18/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4948 - spin_output_loss: 0.1516 - wavelength_output_loss: 0.3000 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9286 - val_loss: 1.6484 - val_spin_output_loss: 0.1764 - val_wavelength_output_loss: 1.4288 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7143
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3753 - spin_output_loss: 0.1312 - wavelength_output_loss: 0.2008 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7137 - val_spin_output_loss: 0.1760 - val_wavelength_output_loss: 1.4945 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7381
# Epoch 20/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3764 - spin_output_loss: 0.1516 - wavelength_output_loss: 0.1816 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7728 - val_spin_output_loss: 0.1770 - val_wavelength_output_loss: 1.5526 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6905
# Epoch 21/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3977 - spin_output_loss: 0.1423 - wavelength_output_loss: 0.2122 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9490 - val_loss: 1.7567 - val_spin_output_loss: 0.1681 - val_wavelength_output_loss: 1.5454 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 22/100
# 4/4 [==============================] - 0s 38ms/step - loss: 0.3635 - spin_output_loss: 0.1246 - wavelength_output_loss: 0.1957 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9286 - val_loss: 1.7962 - val_spin_output_loss: 0.1650 - val_wavelength_output_loss: 1.5880 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 23/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.3829 - spin_output_loss: 0.1416 - wavelength_output_loss: 0.1982 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9694 - val_loss: 1.7807 - val_spin_output_loss: 0.1626 - val_wavelength_output_loss: 1.5749 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 24/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.5369 - spin_output_loss: 0.2846 - wavelength_output_loss: 0.2091 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.9286 - val_loss: 1.7172 - val_spin_output_loss: 0.1644 - val_wavelength_output_loss: 1.5096 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 25/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4480 - spin_output_loss: 0.1702 - wavelength_output_loss: 0.2346 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9286 - val_loss: 1.7019 - val_spin_output_loss: 0.1633 - val_wavelength_output_loss: 1.4953 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 26/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.3949 - spin_output_loss: 0.1532 - wavelength_output_loss: 0.1985 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7106 - val_spin_output_loss: 0.1683 - val_wavelength_output_loss: 1.4991 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 27/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4247 - spin_output_loss: 0.1661 - wavelength_output_loss: 0.2154 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 1.7031 - val_spin_output_loss: 0.1640 - val_wavelength_output_loss: 1.4959 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 28/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3789 - spin_output_loss: 0.1349 - wavelength_output_loss: 0.2007 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9490 - val_loss: 1.7306 - val_spin_output_loss: 0.1581 - val_wavelength_output_loss: 1.5292 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 29/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3589 - spin_output_loss: 0.1588 - wavelength_output_loss: 0.1569 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7474 - val_spin_output_loss: 0.1526 - val_wavelength_output_loss: 1.5515 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 30/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3895 - spin_output_loss: 0.1476 - wavelength_output_loss: 0.1987 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9286 - val_loss: 1.8275 - val_spin_output_loss: 0.1507 - val_wavelength_output_loss: 1.6336 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 31/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4303 - spin_output_loss: 0.1601 - wavelength_output_loss: 0.2269 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9286 - val_loss: 1.8893 - val_spin_output_loss: 0.1526 - val_wavelength_output_loss: 1.6934 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 32/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5165 - spin_output_loss: 0.1951 - wavelength_output_loss: 0.2781 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9184 - val_loss: 1.9099 - val_spin_output_loss: 0.1539 - val_wavelength_output_loss: 1.7126 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 33/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4559 - spin_output_loss: 0.1949 - wavelength_output_loss: 0.2178 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.9286 - val_loss: 1.8433 - val_spin_output_loss: 0.1622 - val_wavelength_output_loss: 1.6378 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 34/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4076 - spin_output_loss: 0.1522 - wavelength_output_loss: 0.2121 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9388 - val_loss: 1.6628 - val_spin_output_loss: 0.1660 - val_wavelength_output_loss: 1.4535 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 35/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5058 - spin_output_loss: 0.1700 - wavelength_output_loss: 0.2926 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.8878 - val_loss: 1.4733 - val_spin_output_loss: 0.1655 - val_wavelength_output_loss: 1.2645 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7619
# Epoch 36/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4193 - spin_output_loss: 0.1454 - wavelength_output_loss: 0.2306 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9286 - val_loss: 1.4953 - val_spin_output_loss: 0.1629 - val_wavelength_output_loss: 1.2891 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7381
# Epoch 37/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5924 - spin_output_loss: 0.3514 - wavelength_output_loss: 0.1977 - spin_output_accuracy: 0.8776 - wavelength_output_accuracy: 0.9388 - val_loss: 1.6337 - val_spin_output_loss: 0.1687 - val_wavelength_output_loss: 1.4217 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.7381
# Epoch 38/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3913 - spin_output_loss: 0.1486 - wavelength_output_loss: 0.1993 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.9184 - val_loss: 1.7107 - val_spin_output_loss: 0.1717 - val_wavelength_output_loss: 1.4957 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 39/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4178 - spin_output_loss: 0.2094 - wavelength_output_loss: 0.1650 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7839 - val_spin_output_loss: 0.1673 - val_wavelength_output_loss: 1.5733 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 40/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3071 - spin_output_loss: 0.1451 - wavelength_output_loss: 0.1186 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9796 - val_loss: 1.8679 - val_spin_output_loss: 0.1653 - val_wavelength_output_loss: 1.6592 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 41/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3314 - spin_output_loss: 0.1538 - wavelength_output_loss: 0.1341 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9694 - val_loss: 1.8793 - val_spin_output_loss: 0.1620 - val_wavelength_output_loss: 1.6738 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 42/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3370 - spin_output_loss: 0.1164 - wavelength_output_loss: 0.1772 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9388 - val_loss: 1.8320 - val_spin_output_loss: 0.1537 - val_wavelength_output_loss: 1.6348 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 43/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4077 - spin_output_loss: 0.1768 - wavelength_output_loss: 0.1874 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.9388 - val_loss: 1.9807 - val_spin_output_loss: 0.1416 - val_wavelength_output_loss: 1.7957 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 44/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4890 - spin_output_loss: 0.1802 - wavelength_output_loss: 0.2653 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9082 - val_loss: 1.8119 - val_spin_output_loss: 0.1453 - val_wavelength_output_loss: 1.6232 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3544 - spin_output_loss: 0.1628 - wavelength_output_loss: 0.1482 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7005 - val_spin_output_loss: 0.1557 - val_wavelength_output_loss: 1.5013 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 46/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3675 - spin_output_loss: 0.1596 - wavelength_output_loss: 0.1644 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7142 - val_spin_output_loss: 0.1593 - val_wavelength_output_loss: 1.5114 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 47/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3495 - spin_output_loss: 0.1533 - wavelength_output_loss: 0.1528 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9592 - val_loss: 1.7700 - val_spin_output_loss: 0.1576 - val_wavelength_output_loss: 1.5690 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 48/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3984 - spin_output_loss: 0.1689 - wavelength_output_loss: 0.1860 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9592 - val_loss: 1.8619 - val_spin_output_loss: 0.1574 - val_wavelength_output_loss: 1.6609 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 49/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3821 - spin_output_loss: 0.1553 - wavelength_output_loss: 0.1832 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9286 - val_loss: 1.7173 - val_spin_output_loss: 0.1748 - val_wavelength_output_loss: 1.4989 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 50/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3892 - spin_output_loss: 0.1390 - wavelength_output_loss: 0.2066 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9082 - val_loss: 1.5842 - val_spin_output_loss: 0.1896 - val_wavelength_output_loss: 1.3511 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.6905
# Epoch 51/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3641 - spin_output_loss: 0.1289 - wavelength_output_loss: 0.1916 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9388 - val_loss: 1.6569 - val_spin_output_loss: 0.1832 - val_wavelength_output_loss: 1.4302 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.6905
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3206 - spin_output_loss: 0.1114 - wavelength_output_loss: 0.1656 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9286 - val_loss: 1.7209 - val_spin_output_loss: 0.1769 - val_wavelength_output_loss: 1.5004 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 53/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3289 - spin_output_loss: 0.1368 - wavelength_output_loss: 0.1485 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9490 - val_loss: 1.6649 - val_spin_output_loss: 0.1756 - val_wavelength_output_loss: 1.4457 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 54/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.2684 - spin_output_loss: 0.0936 - wavelength_output_loss: 0.1312 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9796 - val_loss: 1.6684 - val_spin_output_loss: 0.1748 - val_wavelength_output_loss: 1.4500 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 55/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3970 - spin_output_loss: 0.1465 - wavelength_output_loss: 0.2068 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9286 - val_loss: 1.8713 - val_spin_output_loss: 0.1661 - val_wavelength_output_loss: 1.6615 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 56/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5178 - spin_output_loss: 0.1816 - wavelength_output_loss: 0.2926 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9286 - val_loss: 1.8160 - val_spin_output_loss: 0.1654 - val_wavelength_output_loss: 1.6070 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 57/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5062 - spin_output_loss: 0.2071 - wavelength_output_loss: 0.2554 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.9388 - val_loss: 1.6602 - val_spin_output_loss: 0.1784 - val_wavelength_output_loss: 1.4381 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667
# Epoch 58/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3788 - spin_output_loss: 0.1258 - wavelength_output_loss: 0.2093 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9286 - val_loss: 1.6080 - val_spin_output_loss: 0.2000 - val_wavelength_output_loss: 1.3643 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.6667
# Epoch 59/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4205 - spin_output_loss: 0.1184 - wavelength_output_loss: 0.2584 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9184 - val_loss: 1.6334 - val_spin_output_loss: 0.2094 - val_wavelength_output_loss: 1.3803 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.6667
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3796 - spin_output_loss: 0.1437 - wavelength_output_loss: 0.1922 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9490 - val_loss: 1.7926 - val_spin_output_loss: 0.2033 - val_wavelength_output_loss: 1.5456 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.5714
# Epoch 61/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4788 - spin_output_loss: 0.1773 - wavelength_output_loss: 0.2577 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.9286 - val_loss: 2.1013 - val_spin_output_loss: 0.1922 - val_wavelength_output_loss: 1.8654 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.5476
# Epoch 62/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5408 - spin_output_loss: 0.1577 - wavelength_output_loss: 0.3394 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9286 - val_loss: 2.3147 - val_spin_output_loss: 0.1913 - val_wavelength_output_loss: 2.0797 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5000
# Epoch 63/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5378 - spin_output_loss: 0.1147 - wavelength_output_loss: 0.3794 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9082 - val_loss: 2.3645 - val_spin_output_loss: 0.1901 - val_wavelength_output_loss: 2.1308 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 64/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4829 - spin_output_loss: 0.0901 - wavelength_output_loss: 0.3491 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.8980 - val_loss: 2.2606 - val_spin_output_loss: 0.1866 - val_wavelength_output_loss: 2.0304 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 65/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5196 - spin_output_loss: 0.1676 - wavelength_output_loss: 0.3083 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9184 - val_loss: 2.0447 - val_spin_output_loss: 0.1687 - val_wavelength_output_loss: 1.8324 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4265 - spin_output_loss: 0.1370 - wavelength_output_loss: 0.2459 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9082 - val_loss: 1.9109 - val_spin_output_loss: 0.1482 - val_wavelength_output_loss: 1.7191 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 67/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5567 - spin_output_loss: 0.1158 - wavelength_output_loss: 0.3973 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.8776 - val_loss: 3.0670 - val_spin_output_loss: 0.1359 - val_wavelength_output_loss: 2.8875 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.4762
# Epoch 68/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7427 - spin_output_loss: 0.1107 - wavelength_output_loss: 0.5884 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8367 - val_loss: 3.4860 - val_spin_output_loss: 0.1433 - val_wavelength_output_loss: 3.2990 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 69/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7943 - spin_output_loss: 0.1627 - wavelength_output_loss: 0.5880 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.8469 - val_loss: 3.4034 - val_spin_output_loss: 0.1617 - val_wavelength_output_loss: 3.1980 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 70/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8008 - spin_output_loss: 0.1654 - wavelength_output_loss: 0.5917 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.8367 - val_loss: 3.1889 - val_spin_output_loss: 0.1742 - val_wavelength_output_loss: 2.9710 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 71/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6799 - spin_output_loss: 0.1065 - wavelength_output_loss: 0.5296 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.8673 - val_loss: 2.9056 - val_spin_output_loss: 0.1819 - val_wavelength_output_loss: 2.6800 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 72/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6054 - spin_output_loss: 0.0969 - wavelength_output_loss: 0.4649 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.8776 - val_loss: 2.4962 - val_spin_output_loss: 0.1954 - val_wavelength_output_loss: 2.2571 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.5476
# Epoch 73/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5188 - spin_output_loss: 0.0946 - wavelength_output_loss: 0.3804 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9184 - val_loss: 2.1672 - val_spin_output_loss: 0.1921 - val_wavelength_output_loss: 1.9314 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 74/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5799 - spin_output_loss: 0.1268 - wavelength_output_loss: 0.4094 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.8878 - val_loss: 1.8809 - val_spin_output_loss: 0.1916 - val_wavelength_output_loss: 1.6456 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5385 - spin_output_loss: 0.1736 - wavelength_output_loss: 0.3212 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8571 - val_loss: 1.7892 - val_spin_output_loss: 0.1987 - val_wavelength_output_loss: 1.5467 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6082 - spin_output_loss: 0.1609 - wavelength_output_loss: 0.4036 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8878 - val_loss: 1.8876 - val_spin_output_loss: 0.1842 - val_wavelength_output_loss: 1.6598 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 77/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5316 - spin_output_loss: 0.1191 - wavelength_output_loss: 0.3688 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.8776 - val_loss: 1.8870 - val_spin_output_loss: 0.1719 - val_wavelength_output_loss: 1.6714 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 78/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4802 - spin_output_loss: 0.1096 - wavelength_output_loss: 0.3269 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9082 - val_loss: 1.9755 - val_spin_output_loss: 0.1598 - val_wavelength_output_loss: 1.7720 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 79/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4748 - spin_output_loss: 0.1155 - wavelength_output_loss: 0.3156 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8980 - val_loss: 2.5922 - val_spin_output_loss: 0.1612 - val_wavelength_output_loss: 2.3873 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 80/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6072 - spin_output_loss: 0.1668 - wavelength_output_loss: 0.3967 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.8776 - val_loss: 2.8924 - val_spin_output_loss: 0.1540 - val_wavelength_output_loss: 2.6947 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 81/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6355 - spin_output_loss: 0.1063 - wavelength_output_loss: 0.4854 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8469 - val_loss: 2.7848 - val_spin_output_loss: 0.1548 - val_wavelength_output_loss: 2.5862 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6429
# Epoch 82/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5984 - spin_output_loss: 0.1286 - wavelength_output_loss: 0.4260 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8673 - val_loss: 2.7799 - val_spin_output_loss: 0.1640 - val_wavelength_output_loss: 2.5722 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 83/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6194 - spin_output_loss: 0.1600 - wavelength_output_loss: 0.4157 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8673 - val_loss: 2.7562 - val_spin_output_loss: 0.1751 - val_wavelength_output_loss: 2.5374 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 84/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4512 - spin_output_loss: 0.0947 - wavelength_output_loss: 0.3127 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9184 - val_loss: 2.6716 - val_spin_output_loss: 0.1776 - val_wavelength_output_loss: 2.4502 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 85/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5890 - spin_output_loss: 0.1732 - wavelength_output_loss: 0.3720 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9082 - val_loss: 2.5286 - val_spin_output_loss: 0.1791 - val_wavelength_output_loss: 2.3057 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 86/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5536 - spin_output_loss: 0.1627 - wavelength_output_loss: 0.3470 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.9082 - val_loss: 2.4586 - val_spin_output_loss: 0.1796 - val_wavelength_output_loss: 2.2352 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5169 - spin_output_loss: 0.1474 - wavelength_output_loss: 0.3257 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.9184 - val_loss: 2.3353 - val_spin_output_loss: 0.1747 - val_wavelength_output_loss: 2.1168 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5476
# Epoch 88/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4342 - spin_output_loss: 0.1231 - wavelength_output_loss: 0.2673 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.9184 - val_loss: 2.2967 - val_spin_output_loss: 0.1778 - val_wavelength_output_loss: 2.0751 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5359 - spin_output_loss: 0.1821 - wavelength_output_loss: 0.3099 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9082 - val_loss: 2.4064 - val_spin_output_loss: 0.1629 - val_wavelength_output_loss: 2.1997 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 90/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5085 - spin_output_loss: 0.1301 - wavelength_output_loss: 0.3346 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8673 - val_loss: 2.6363 - val_spin_output_loss: 0.1669 - val_wavelength_output_loss: 2.4256 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 91/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6161 - spin_output_loss: 0.1598 - wavelength_output_loss: 0.4125 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.8980 - val_loss: 2.6386 - val_spin_output_loss: 0.1705 - val_wavelength_output_loss: 2.4242 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5238
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5700 - spin_output_loss: 0.0816 - wavelength_output_loss: 0.4446 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9082 - val_loss: 2.5955 - val_spin_output_loss: 0.1646 - val_wavelength_output_loss: 2.3871 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 93/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4851 - spin_output_loss: 0.1239 - wavelength_output_loss: 0.3173 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.9184 - val_loss: 2.4638 - val_spin_output_loss: 0.1562 - val_wavelength_output_loss: 2.2638 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 94/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4965 - spin_output_loss: 0.1023 - wavelength_output_loss: 0.3503 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.8776 - val_loss: 2.3324 - val_spin_output_loss: 0.1503 - val_wavelength_output_loss: 2.1382 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5714
# Epoch 95/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4686 - spin_output_loss: 0.1109 - wavelength_output_loss: 0.3138 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.8776 - val_loss: 2.2316 - val_spin_output_loss: 0.1493 - val_wavelength_output_loss: 2.0384 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 96/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4770 - spin_output_loss: 0.1818 - wavelength_output_loss: 0.2512 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.9082 - val_loss: 2.1343 - val_spin_output_loss: 0.1446 - val_wavelength_output_loss: 1.9458 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6190
# Epoch 97/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4247 - spin_output_loss: 0.1407 - wavelength_output_loss: 0.2401 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9286 - val_loss: 2.1032 - val_spin_output_loss: 0.1328 - val_wavelength_output_loss: 1.9264 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.5952
# Epoch 98/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4490 - spin_output_loss: 0.1508 - wavelength_output_loss: 0.2542 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9388 - val_loss: 2.0694 - val_spin_output_loss: 0.1349 - val_wavelength_output_loss: 1.8904 - val_spin_output_accuracy: 0.9762 - val_wavelength_output_accuracy: 0.5952
# Epoch 99/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4478 - spin_output_loss: 0.1413 - wavelength_output_loss: 0.2625 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.9184 - val_loss: 2.0166 - val_spin_output_loss: 0.1376 - val_wavelength_output_loss: 1.8351 - val_spin_output_accuracy: 0.9762 - val_wavelength_output_accuracy: 0.5952
# Epoch 100/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3895 - spin_output_loss: 0.1008 - wavelength_output_loss: 0.2447 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.9490 - val_loss: 1.8745 - val_spin_output_loss: 0.1348 - val_wavelength_output_loss: 1.6956 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.6667

# %%
# model = load_model('model()_.h5')

# %%
# print the training loss and accuracy
training_history = model.history
print('Training Loss:', min(training_history.history['loss']))
# print the minimum training loss
# print('Minimum Training Loss:', min(history.history['loss']))

print('Training Spin Loss:', min(training_history.history['spin_output_loss']))
print('Training Wavelength Loss:', min(training_history.history['wavelength_output_loss']))

print('Training Spin Accuracy:', min(training_history.history['spin_output_accuracy']))
print('Training Wavelength Accuracy:', max(training_history.history['wavelength_output_accuracy']))


#ptint the minimum validation loss
print('Minimum Test Loss:', min(training_history.history['val_loss']))
print('Val Spin Loss:', min(training_history.history['val_spin_output_loss']))
print('Val Wavelength Loss:', min(training_history.history['val_wavelength_output_loss']))



print('Val Spin Accuracy:', min(training_history.history['val_spin_output_accuracy']))
print('Val Wavelength Accuracy:', max(training_history.history['val_wavelength_output_accuracy']))
# Out:
# Training Loss: 0.2683960795402527
# Training Spin Loss: 0.08159638196229935
# Training Wavelength Loss: 0.11864709109067917
# Training Spin Accuracy: 0.8775510191917419
# Training Wavelength Accuracy: 0.9795918464660645
# Minimum Test Loss: 1.4732555150985718
# Val Spin Loss: 0.13282887637615204
# Val Wavelength Loss: 1.2644819021224976
# Val Spin Accuracy: 0.9285714030265808
# Val Wavelength Accuracy: 0.761904776096344

# %%
# evaluate the model
loss, spin_loss, wavelength_loss, spin_accuracy, wavelength_accuracy = model.evaluate(X_test, [y_spin_test, y_wavelength_test])

print('Spin Loss:', spin_loss)
print('Wavelength Loss:', wavelength_loss)
print('Spin Accuracy:', spin_accuracy)
print('Wavelength Accuracy:', wavelength_accuracy)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8745 - spin_output_loss: 0.1348 - wavelength_output_loss: 1.6956 - spin_output_accuracy: 0.9524 - wavelength_output_accuracy: 0.6667
# Spin Loss: 0.13481129705905914
# Wavelength Loss: 1.6956051588058472
# Spin Accuracy: 0.9523809552192688
# Wavelength Accuracy: 0.6666666865348816

# %%
model.summary()
# draw the model

from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)

# save the model
model.save('model_0430.h5')
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 3)]                  0         []
#
#  dense_49 (Dense)            (None, 128)                  512       ['input_8[0][0]']
#
#  batch_normalization_37 (Ba  (None, 128)                  512       ['dense_49[0][0]']
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 128)                  0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  dense_50 (Dense)            (None, 256)                  33024     ['dropout_21[0][0]']
#
#  batch_normalization_38 (Ba  (None, 256)                  1024      ['dense_50[0][0]']
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 256)                  0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  dense_53 (Dense)            (None, 256)                  33024     ['dense_49[0][0]']
#
#  dense_51 (Dense)            (None, 64)                   16448     ['dropout_22[0][0]']
#
#  dense_54 (Dense)            (None, 512)                  131584    ['dense_53[0][0]']
#
#  batch_normalization_39 (Ba  (None, 64)                   256       ['dense_51[0][0]']
#  tchNormalization)
#
#  dense_55 (Dense)            (None, 128)                  65664     ['dense_54[0][0]']
#
#  dropout_23 (Dropout)        (None, 64)                   0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  dense_56 (Dense)            (None, 32)                   4128      ['dense_55[0][0]']
#
#  dense_52 (Dense)            (None, 128)                  8320      ['dropout_23[0][0]']
#
#  batch_normalization_42 (Ba  (None, 32)                   128       ['dense_56[0][0]']
#  tchNormalization)
#
#  spin_output (Dense)         (None, 1)                    129       ['dense_52[0][0]']
#
#  wavelength_output (Dense)   (None, 14)                   462       ['batch_normalization_42[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 295215 (1.13 MB)
# Trainable params: 294255 (1.12 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# /home/guoguo/anaconda3/envs/photocurrent/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# draw the model structure
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
img = plt.imread('model.png')
plt.imshow(img)
plt.show()

# %%
# draw the accuracy of the model
from sklearn.metrics import accuracy_score

y_pred_w = model.predict(X_test)[1] # 取出Wavelength的预测结果
y_pred_w = np.argmax(y_pred_w, axis=1) + 1  # 取出最大值的索引，加1是因为to_categorical从0开始索引
y_true_w = np.argmax(y_wavelength_test, axis=1) + 1

accuracy = accuracy_score(y_true_w, y_pred_w)
print('Accuracy:', accuracy)
# Out:
# 2/2 [==============================] - 0s 2ms/step
# Accuracy: 0.6666666666666666

# %%
# draw the confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
fig = plt.figure(figsize=(10, 8))
confusion = confusion_matrix(y_true_w, y_pred_w)
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', square=True, annot_kws={"size": 14})
# chaneg the x,y from 1-7
plt.xticks(np.arange(7) + 0.5, range(1, 8), fontsize=12)
plt.yticks(np.arange(7) + 0.5, range(1, 8), fontsize=12)
# add the unit（um） of x,y axis

plt.xlabel('Predicted Wavelength(m)', fontsize=14)
plt.ylabel('True Wavelength(m)', fontsize=14)
# plt.gca().invert_yaxis()
plt.show()

# %%
# draw the confusion matrix of spin

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = np.round(y_pred_s).flatten()  # 四舍五入
y_true_s = y_spin_test.flatten()

confusion = confusion_matrix(y_true_s, y_pred_s)
fig = plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()ß
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
# draw the confusion matrix of spin

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = np.round(y_pred_s).flatten()  # 四舍五入
y_true_s = y_spin_test.flatten()

confusion = confusion_matrix(y_true_s, y_pred_s)
fig = plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()ß
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
# draw the ROC curve of the model for spin and wavelength prediction
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = y_pred_s.flatten()
y_true_s = y_spin_test

y_pred_w = model.predict(X_test)[1]  # 取出Wavelength的预测结果
y_pred_w = y_pred_w.flatten()
y_true_w = np.argmax(y_wavelength_test, axis=1)


# draw the ROC curve of spin and wavelength in the same figure
fig = plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_true_s, y_pred_s)
plt.plot(fpr, tpr, label='Spin')
fpr, tpr, thresholds = roc_curve(y_wavelength_test.ravel(), y_pred_w.ravel())
plt.plot(fpr, tpr, label='Wavelength')
# plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.grid( linestyle='--', color='gray', linewidth=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 1ms/step
# 2/2 [==============================] - 0s 1ms/step

# %%
# plot the training loss of the model
import matplotlib.pyplot as plt
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# test the model use a new data
X_new = np.array([[0.53, -0.16, 1]])
y_pred = model.predict(X_new)
if y_pred[0] < 0.5:
    y_pred[0] = 0
else:
    y_pred[0] = 1

y_pred[1] = np.argmax(y_pred[1])
print('Spin:', y_pred[0])
print('Wavelength range:', y_pred[1])
# print('true_w',y_wavelength_test)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# Spin: 0
# Wavelength range: 1

# %%
# test the model use a new data
X_new = np.array([[-0.01, 1, 0.54]])
y_pred = model.predict(X_new)
if y_pred[0] < 0.5:
    y_pred[0] = 0
else:
    y_pred[0] = 1

y_pred[1] = np.argmax(y_pred[1]) 
print('Spin:', y_pred[0])
print('Wavelength range:', y_pred[1])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Spin: 1
# Wavelength range: 12

# %%
y_pred = model.predict(X_new)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [array([[0.00085186]], dtype=float32), array([[1.3449675e-04, 1.1146749e-04, 1.0514270e-04, 2.8234077e-05,
#         3.3917233e-05, 7.1379788e-02, 9.2820692e-01]], dtype=float32)]

# %%
# lode a new data from excel
file_path = 'Dataset_MLtest_0.5.xlsx'
data = pd.read_excel(file_path)
X = data[['x1', 'x2', 'x3']].values
y_spin = data[['spin']].values
y_wavelength = to_categorical(data['wavelength'].values, num_classes=14)  # 减1是因为to_categorical从0开始索引

# %%
y_pred = model.predict(X)
y_pred_s = y_pred[0].flatten()
y_pred_s = np.round(y_pred_s)
y_true_s = y_spin.flatten()
spin_acc = accuracy_score(y_true_s, y_pred_s)
print('Spin Accuracy:', spin_acc)
y_pred_w = y_pred[1]
# save the y_pred_w, y_true_w to a excel file

df = pd.DataFrame({'y_pred_w': y_pred_w.flatten()})
df.to_excel('wavelength_prediction.xlsx', index=False)
df = pd.DataFrame({'y_true_w': y_true_w})
df.to_excel('wavelength_true.xlsx', index=False)


y_pred_w = np.argmax(y_pred_w, axis=1) 
y_true_w = np.argmax(y_wavelength, axis=1) 
wavelength_acc = accuracy_score(y_true_w, y_pred_w)
print('Wavelength Accuracy:', wavelength_acc)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# Spin Accuracy: 1.0
# Wavelength Accuracy: 0.875

# %%
# draw the confusion matrix of spin and wavelength



fig = plt.figure(figsize=(6, 4))
confusion = confusion_matrix(y_true_s, y_pred_s)
sns.heatmap(confusion, annot=True, fmt='d', cmap='Reds', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()

# %%
# all_calss = np.arange(1, 8)
print(y_true_w)
print(y_pred_w)

all_classes = np.arange(0,14 )  # 从1到7的类别

# 生成混淆矩阵，明确指定类别标签
confusion = confusion_matrix(y_true_w, y_pred_w, labels=all_classes)

# 绘制热图
fig = plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Reds', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Wavelength (m)', fontsize=14)
plt.ylabel('True Wavelength (m)', fontsize=14)
plt.xticks(np.arange(len(all_classes)) + 0.5, all_classes, fontsize=12)  # 设置x轴标签
plt.yticks(np.arange(len(all_classes)) + 0.5, all_classes, fontsize=12)  # 设置y轴标签
plt.title('Confusion Matrix')
plt.show()
# Out:
# [ 1  1  3  3  6  6 12 12]
# [ 1  1  3  3  6  6 11 12]
