# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2024-05-01 11:24:05.863400: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 11:24:05.901212: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-01 11:24:05.901234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-01 11:24:05.902339: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-01 11:24:05.908146: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-01 11:24:05.908701: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-01 11:24:06.542404: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# 载入数据
file_path = 'Dataset_new.xlsx'
data = pd.read_excel(file_path)

# %%
print(data.columns)
# wave_01 的shape
print(data['wave_01'].shape)
# Out:
# Index(['x1', 'x2', 'x3', 'wlt', 'wave_half_f', 'wave_half', 'wave_01_r',
#        'wave_01f', 'wave_01', 'wavelength', 'spin', 'Unnamed: 11', 'range',
#        'label'],
#       dtype='object')
# (140,)

# %%
# 特征和标签
X = data[['x1', 'x2', 'x3']].values
# y_spin = data[['y1', 'y2', 'y3']].values
y_spin = data[['spin']].values
y_wavelength = to_categorical(data['wave_01'].values, num_classes=70)

# %%
# 拆分数据集
X_train, X_test, y_spin_train, y_spin_test, y_wavelength_train, y_wavelength_test = train_test_split(
    X, y_spin, y_wavelength, test_size=0.3, random_state=42)# stratify=y_wavelength.argmax(axis=1)


# nn model
input_layer = Input(shape=(X.shape[1],))
hidden_layer_1 = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(input_layer)
bn1 = BatchNormalization()(hidden_layer_1)
drop_out_1 = Dropout(0.3)(bn1)  # 调整Dropout比率
hidden_layer_2 = Dense(256, activation='relu')(drop_out_1)
bn2 = BatchNormalization()(hidden_layer_2)
drop_out_2 = Dropout(0.3)(bn2)
hidden_layer_3 = Dense(64, activation='relu')(drop_out_2)
bn3 = BatchNormalization()(hidden_layer_3)
drop_out_3 = Dropout(0.3)(bn3)
hidden_layer_4 = Dense(128, activation='relu')(drop_out_3)
bn4 = BatchNormalization()(hidden_layer_4)
hidden_layer_5 = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(hidden_layer_1)
# bn5 = BatchNormalization()(hidden_layer_5)
hidden_layer_6 = Dense(256, activation='relu')(hidden_layer_5)
# bn6 = BatchNormalization()(hidden_layer_6)
# hidden_layer_7 = Dense(256, activation='relu')(hidden_layer_6)
# bn7 = BatchNormalization()(hidden_layer_7)
hidden_layer_8 = Dense(128, activation='relu',kernel_regularizer=l2(0.01))(hidden_layer_6)
bn8 = BatchNormalization()(hidden_layer_8)
# hidden_layer_9 = Dense(64, activation='relu')(hidden_layer_8)
# bn9 = BatchNormalization()(hidden_layer_9)
hidden_layer_10 = Dense(128, activation='relu')(hidden_layer_8)
bn10 = BatchNormalization()(hidden_layer_10)
# hidden_layer_11 = Dense(128, activation='relu')(hidden_layer_10)
# bn11 = BatchNormalization()(hidden_layer_11)
# hidden_layer_12 = Dense(128, activation='relu')(hidden_layer_11)


# 输出层，确保两个输出连接到同一层
spin_output = Dense(1, activation='sigmoid', name='spin_output', kernel_regularizer=l2(0.001))(hidden_layer_4)
wavelength_output = Dense(y_wavelength.shape[1], activation='softmax', name='wavelength_output', kernel_regularizer=l2(0.001))(hidden_layer_10)

# %%
# 创建模型
model = Model(inputs=input_layer, outputs=[spin_output, wavelength_output])

# 损失函数：前三个输出用二元交叉熵，最后一个输出用分类交叉熵
losses = {
    'spin_output': 'binary_crossentropy',
    'wavelength_output': 'categorical_crossentropy'
}

# 编译模型
model.compile(optimizer=Adam(), loss=losses, metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# %%
# 训练模型
model.fit(X_train, [y_spin_train, y_wavelength_train], 
          validation_data=(X_test, [y_spin_test, y_wavelength_test]), 
          epochs=100, 
          batch_size=32)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 30ms/step - loss: 2.3185 - spin_output_loss: 0.1650 - wavelength_output_loss: 1.8602 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.3367 - val_loss: 7.7528 - val_spin_output_loss: 0.2432 - val_wavelength_output_loss: 7.2166 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 2.2852 - spin_output_loss: 0.1580 - wavelength_output_loss: 1.8343 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.3265 - val_loss: 7.7150 - val_spin_output_loss: 0.2365 - val_wavelength_output_loss: 7.1858 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 3/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2531 - spin_output_loss: 0.1557 - wavelength_output_loss: 1.8047 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.3571 - val_loss: 7.6188 - val_spin_output_loss: 0.2410 - val_wavelength_output_loss: 7.0849 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 4/100
# 4/4 [==============================] - 0s 9ms/step - loss: 2.2302 - spin_output_loss: 0.1254 - wavelength_output_loss: 1.8118 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.3367 - val_loss: 7.6027 - val_spin_output_loss: 0.2324 - val_wavelength_output_loss: 7.0773 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 5/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.2395 - spin_output_loss: 0.1575 - wavelength_output_loss: 1.7893 - spin_output_accuracy: 0.9184 - wavelength_output_accuracy: 0.3776 - val_loss: 7.6492 - val_spin_output_loss: 0.2347 - val_wavelength_output_loss: 7.1222 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 6/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.2841 - spin_output_loss: 0.1711 - wavelength_output_loss: 1.8208 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.3163 - val_loss: 7.5420 - val_spin_output_loss: 0.2480 - val_wavelength_output_loss: 7.0018 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 7/100
# 4/4 [==============================] - 0s 11ms/step - loss: 2.3334 - spin_output_loss: 0.2210 - wavelength_output_loss: 1.8202 - spin_output_accuracy: 0.9082 - wavelength_output_accuracy: 0.3265 - val_loss: 7.5235 - val_spin_output_loss: 0.2529 - val_wavelength_output_loss: 6.9785 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 8/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.3136 - spin_output_loss: 0.1927 - wavelength_output_loss: 1.8290 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.2857 - val_loss: 7.6153 - val_spin_output_loss: 0.2548 - val_wavelength_output_loss: 7.0686 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0238
# Epoch 9/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.2184 - spin_output_loss: 0.1225 - wavelength_output_loss: 1.8040 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.3367 - val_loss: 7.6146 - val_spin_output_loss: 0.2713 - val_wavelength_output_loss: 7.0509 - val_spin_output_accuracy: 0.8571 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 10/100
# 4/4 [==============================] - 0s 16ms/step - loss: 2.1958 - spin_output_loss: 0.1303 - wavelength_output_loss: 1.7730 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.3367 - val_loss: 7.6243 - val_spin_output_loss: 0.2694 - val_wavelength_output_loss: 7.0622 - val_spin_output_accuracy: 0.8571 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 11/100
# 4/4 [==============================] - 0s 18ms/step - loss: 2.2196 - spin_output_loss: 0.1386 - wavelength_output_loss: 1.7883 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.3469 - val_loss: 7.7528 - val_spin_output_loss: 0.2805 - val_wavelength_output_loss: 7.1796 - val_spin_output_accuracy: 0.8571 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.3843 - spin_output_loss: 0.1603 - wavelength_output_loss: 1.9313 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.2653 - val_loss: 7.8394 - val_spin_output_loss: 0.2796 - val_wavelength_output_loss: 7.2675 - val_spin_output_accuracy: 0.8333 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.4182 - spin_output_loss: 0.1907 - wavelength_output_loss: 1.9354 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.3469 - val_loss: 7.8905 - val_spin_output_loss: 0.2711 - val_wavelength_output_loss: 7.3274 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 14/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.4357 - spin_output_loss: 0.1414 - wavelength_output_loss: 2.0021 - spin_output_accuracy: 0.9796 - wavelength_output_accuracy: 0.3163 - val_loss: 7.8184 - val_spin_output_loss: 0.2624 - val_wavelength_output_loss: 7.2642 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0238
# Epoch 15/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3898 - spin_output_loss: 0.1220 - wavelength_output_loss: 1.9765 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.3776 - val_loss: 7.6068 - val_spin_output_loss: 0.2595 - val_wavelength_output_loss: 7.0571 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0238
# Epoch 16/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.3524 - spin_output_loss: 0.1202 - wavelength_output_loss: 1.9419 - spin_output_accuracy: 0.9694 - wavelength_output_accuracy: 0.2755 - val_loss: 7.2469 - val_spin_output_loss: 0.2564 - val_wavelength_output_loss: 6.7000 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0476
# Epoch 17/100
# 4/4 [==============================] - 0s 20ms/step - loss: 2.3288 - spin_output_loss: 0.1333 - wavelength_output_loss: 1.9051 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.3265 - val_loss: 7.2324 - val_spin_output_loss: 0.2598 - val_wavelength_output_loss: 6.6829 - val_spin_output_accuracy: 0.8810 - val_wavelength_output_accuracy: 0.0238
# Epoch 18/100
# 4/4 [==============================] - 0s 25ms/step - loss: 2.2543 - spin_output_loss: 0.1715 - wavelength_output_loss: 1.7938 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.3776 - val_loss: 7.2536 - val_spin_output_loss: 0.2551 - val_wavelength_output_loss: 6.7105 - val_spin_output_accuracy: 0.9048 - val_wavelength_output_accuracy: 0.0238
# Epoch 19/100
# 4/4 [==============================] - 0s 37ms/step - loss: 2.2885 - spin_output_loss: 0.1702 - wavelength_output_loss: 1.8302 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.3367 - val_loss: 7.2728 - val_spin_output_loss: 0.2432 - val_wavelength_output_loss: 6.7411 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 20/100
# 4/4 [==============================] - 0s 47ms/step - loss: 2.2406 - spin_output_loss: 0.1237 - wavelength_output_loss: 1.8284 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.3469 - val_loss: 7.4278 - val_spin_output_loss: 0.2367 - val_wavelength_output_loss: 6.9026 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.0238
# Epoch 21/100
# 4/4 [==============================] - 0s 46ms/step - loss: 2.4151 - spin_output_loss: 0.1479 - wavelength_output_loss: 1.9787 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.3265 - val_loss: 7.5128 - val_spin_output_loss: 0.2256 - val_wavelength_output_loss: 6.9982 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.0238
# Epoch 22/100
# 4/4 [==============================] - 0s 36ms/step - loss: 2.4869 - spin_output_loss: 0.2192 - wavelength_output_loss: 1.9786 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.3163 - val_loss: 7.1130 - val_spin_output_loss: 0.2301 - val_wavelength_output_loss: 6.5930 - val_spin_output_accuracy: 0.9286 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch
- val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 92/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.8899 - spin_output_loss: 0.1499 - wavelength_output_loss: 1.4362 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.4694 - val_loss: 7.8141 - val_spin_output_loss: 0.1786 - val_wavelength_output_loss: 7.3312 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 93/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.8029 - spin_output_loss: 0.1467 - wavelength_output_loss: 1.3519 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.5408 - val_loss: 7.9072 - val_spin_output_loss: 0.1785 - val_wavelength_output_loss: 7.4241 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 94/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.7990 - spin_output_loss: 0.1388 - wavelength_output_loss: 1.3555 - spin_output_accuracy: 0.9286 - wavelength_output_accuracy: 0.4490 - val_loss: 7.8916 - val_spin_output_loss: 0.1769 - val_wavelength_output_loss: 7.4088 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0238
# Epoch 95/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.8215 - spin_output_loss: 0.1519 - wavelength_output_loss: 1.3633 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.4898 - val_loss: 7.9122 - val_spin_output_loss: 0.1847 - val_wavelength_output_loss: 7.4201 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0238
# Epoch 96/100
# 4/4 [==============================] - 0s 17ms/step - loss: 1.7353 - spin_output_loss: 0.1176 - wavelength_output_loss: 1.3101 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.5306 - val_loss: 8.0033 - val_spin_output_loss: 0.1923 - val_wavelength_output_loss: 7.5028 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0238
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.8856 - spin_output_loss: 0.1558 - wavelength_output_loss: 1.4215 - spin_output_accuracy: 0.9592 - wavelength_output_accuracy: 0.4898 - val_loss: 7.8943 - val_spin_output_loss: 0.1798 - val_wavelength_output_loss: 7.4056 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0476
# Epoch 98/100
# 4/4 [==============================] - 0s 50ms/step - loss: 2.0080 - spin_output_loss: 0.1974 - wavelength_output_loss: 1.5013 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.4388 - val_loss: 7.9244 - val_spin_output_loss: 0.1703 - val_wavelength_output_loss: 7.4446 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 99/100
# 4/4 [==============================] - 0s 40ms/step - loss: 1.9296 - spin_output_loss: 0.1448 - wavelength_output_loss: 1.4758 - spin_output_accuracy: 0.9490 - wavelength_output_accuracy: 0.4592 - val_loss: 7.7509 - val_spin_output_loss: 0.1685 - val_wavelength_output_loss: 7.2738 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00
# Epoch 100/100
# 4/4 [==============================] - 0s 36ms/step - loss: 2.0090 - spin_output_loss: 0.1761 - wavelength_output_loss: 1.5242 - spin_output_accuracy: 0.9388 - wavelength_output_accuracy: 0.3980 - val_loss: 7.7269 - val_spin_output_loss: 0.1613 - val_wavelength_output_loss: 7.2571 - val_spin_output_accuracy: 0.9524 - val_wavelength_output_accuracy: 0.0000e+00

# %%
# model = load_model('model()_.h5')

# %%
# print the training loss and accuracy
training_history = model.history
print('Training Loss:', min(training_history.history['loss']))
# print the minimum training loss
# print('Minimum Training Loss:', min(history.history['loss']))

print('Training Spin Loss:', min(training_history.history['spin_output_loss']))
print('Training Wavelength Loss:', min(training_history.history['wavelength_output_loss']))

print('Training Spin Accuracy:', min(training_history.history['spin_output_accuracy']))
print('Training Wavelength Accuracy:', max(training_history.history['wavelength_output_accuracy']))


#ptint the minimum validation loss
print('Minimum Test Loss:', min(training_history.history['val_loss']))
print('Val Spin Loss:', min(training_history.history['val_spin_output_loss']))
print('Val Wavelength Loss:', min(training_history.history['val_wavelength_output_loss']))



print('Val Spin Accuracy:', min(training_history.history['val_spin_output_accuracy']))
print('Val Wavelength Accuracy:', max(training_history.history['val_wavelength_output_accuracy']))
# Out:
# Training Loss: 1.7352885007858276
# Training Spin Loss: 0.09573172777891159
# Training Wavelength Loss: 1.3100589513778687
# Training Spin Accuracy: 0.8877550959587097
# Training Wavelength Accuracy: 0.5408163070678711
# Minimum Test Loss: 6.533559799194336
# Val Spin Loss: 0.1376461237668991
# Val Wavelength Loss: 6.04396915435791
# Val Spin Accuracy: 0.8333333134651184
# Val Wavelength Accuracy: 0.0476190485060215

# %%
# evaluate the model
loss, spin_loss, wavelength_loss, spin_accuracy, wavelength_accuracy = model.evaluate(X_test, [y_spin_test, y_wavelength_test])

print('Spin Loss:', spin_loss)
print('Wavelength Loss:', wavelength_loss)
print('Spin Accuracy:', spin_accuracy)
print('Wavelength Accuracy:', wavelength_accuracy)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 7.7269 - spin_output_loss: 0.1613 - wavelength_output_loss: 7.2571 - spin_output_accuracy: 0.9524 - wavelength_output_accuracy: 0.0000e+00
# Spin Loss: 0.1613364964723587
# Wavelength Loss: 7.257120132446289
# Spin Accuracy: 0.9523809552192688
# Wavelength Accuracy: 0.0

# %%
model.summary()
# draw the model

from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model0431.png', show_shapes=True)

# save the model
model.save('model_0431.h5')
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_8 (InputLayer)        [(None, 3)]                  0         []
#
#  dense_49 (Dense)            (None, 128)                  512       ['input_8[0][0]']
#
#  batch_normalization_37 (Ba  (None, 128)                  512       ['dense_49[0][0]']
#  tchNormalization)
#
#  dropout_21 (Dropout)        (None, 128)                  0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  dense_50 (Dense)            (None, 256)                  33024     ['dropout_21[0][0]']
#
#  batch_normalization_38 (Ba  (None, 256)                  1024      ['dense_50[0][0]']
#  tchNormalization)
#
#  dropout_22 (Dropout)        (None, 256)                  0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  dense_53 (Dense)            (None, 256)                  33024     ['dense_49[0][0]']
#
#  dense_51 (Dense)            (None, 64)                   16448     ['dropout_22[0][0]']
#
#  dense_54 (Dense)            (None, 512)                  131584    ['dense_53[0][0]']
#
#  batch_normalization_39 (Ba  (None, 64)                   256       ['dense_51[0][0]']
#  tchNormalization)
#
#  dense_55 (Dense)            (None, 128)                  65664     ['dense_54[0][0]']
#
#  dropout_23 (Dropout)        (None, 64)                   0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  dense_56 (Dense)            (None, 32)                   4128      ['dense_55[0][0]']
#
#  dense_52 (Dense)            (None, 128)                  8320      ['dropout_23[0][0]']
#
#  batch_normalization_42 (Ba  (None, 32)                   128       ['dense_56[0][0]']
#  tchNormalization)
#
#  spin_output (Dense)         (None, 1)                    129       ['dense_52[0][0]']
#
#  wavelength_output (Dense)   (None, 14)                   462       ['batch_normalization_42[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 295215 (1.13 MB)
# Trainable params: 294255 (1.12 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________
# /home/guoguo/anaconda3/envs/photocurrent/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# draw the model structure
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
img = plt.imread('model.png')
plt.imshow(img)
plt.show()

# %%
# draw the accuracy of the model
from sklearn.metrics import accuracy_score

y_pred_w = model.predict(X_test)[1] # 取出Wavelength的预测结果
y_pred_w = np.argmax(y_pred_w, axis=1)   # 取出最大值的索引，加1是因为to_categorical从0开始索引
y_true_w = np.argmax(y_wavelength_test, axis=1)

accuracy = accuracy_score(y_true_w, y_pred_w)
print('Accuracy:', accuracy)
# print(y_pred_w.shape)
# print(y_true_w.shape)
# print(y_pred_w)
print(np.unique(y_pred_w))
# Out:
# 2/2 [==============================] - 0s 2ms/step
# Accuracy: 0.0
# [ 5  9 13 17 20 21 25 27 30 33 41 42 46 49 51 52 54 60 61 64 67 68]

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define all possible labels
all_labels = np.arange(70)

# Generate the confusion matrix with all labels
confusion = confusion_matrix(y_true_w, y_pred_w, labels=all_labels)

# Plotting
fig = plt.figure(figsize=(120, 100))  # Adjust size as needed
sns.heatmap(confusion, annot=True, fmt='d', cmap='Reds', square=True, annot_kws={"size": 30})

# Setting ticks for all labels from 0 to 69
plt.xticks(np.arange(len(all_labels)), all_labels, rotation=90, fontsize=20)
plt.yticks(np.arange(len(all_labels)), all_labels, fontsize=20)

plt.xlabel('Predicted Wavelength (m)', fontsize=12)
plt.ylabel('True Wavelength (m)', fontsize=12)
plt.show()

# %%
# draw the confusion matrix of spin

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = np.round(y_pred_s).flatten()  # 四舍五入
y_true_s = y_spin_test.flatten()

confusion = confusion_matrix(y_true_s, y_pred_s)
fig = plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
# draw the confusion matrix of spin

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = np.round(y_pred_s).flatten()  # 四舍五入
y_true_s = y_spin_test.flatten()

confusion = confusion_matrix(y_true_s, y_pred_s)
fig = plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()ß
# Out:
# 2/2 [==============================] - 0s 2ms/step

# %%
# draw the ROC curve of the model for spin and wavelength prediction
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

y_pred_s = model.predict(X_test)[0]  # 取出Spin的预测结果
y_pred_s = y_pred_s.flatten()
y_true_s = y_spin_test

y_pred_w = model.predict(X_test)[1]  # 取出Wavelength的预测结果
y_pred_w = y_pred_w.flatten()
y_true_w = np.argmax(y_wavelength_test, axis=1)


# draw the ROC curve of spin and wavelength in the same figure
fig = plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_true_s, y_pred_s)
plt.plot(fpr, tpr, label='Spin')
fpr, tpr, thresholds = roc_curve(y_wavelength_test.ravel(), y_pred_w.ravel())
plt.plot(fpr, tpr, label='Wavelength')
# plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.grid( linestyle='--', color='gray', linewidth=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step

# %%
# plot the training loss of the model
import matplotlib.pyplot as plt
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# test the model use a new data
X_new = np.array([[0.53, -0.16, 1]])
y_pred = model.predict(X_new)
if y_pred[0] < 0.5:
    y_pred[0] = 0
else:
    y_pred[0] = 1

y_pred[1] = np.argmax(y_pred[1])
print('Spin:', y_pred[0])
print('Wavelength range:', y_pred[1])
# print('true_w',y_wavelength_test)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# Spin: 0
# Wavelength range: 1

# %%
# test the model use a new data
X_new = np.array([[-0.01, 1, 0.54]])
y_pred = model.predict(X_new)
if y_pred[0] < 0.5:
    y_pred[0] = 0
else:
    y_pred[0] = 1

y_pred[1] = np.argmax(y_pred[1]) 
print('Spin:', y_pred[0])
print('Wavelength range:', y_pred[1])
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Spin: 1
# Wavelength range: 12

# %%
y_pred = model.predict(X_new)
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [array([[0.00085186]], dtype=float32), array([[1.3449675e-04, 1.1146749e-04, 1.0514270e-04, 2.8234077e-05,
#         3.3917233e-05, 7.1379788e-02, 9.2820692e-01]], dtype=float32)]

# %%
# lode a new data from excel
file_path = 'Dataset_MLtest_0.5.xlsx'
data = pd.read_excel(file_path)
X = data[['x1', 'x2', 'x3']].values
y_spin = data[['spin']].values
y_wavelength = to_categorical(data['wavelength'].values, num_classes=14)  # 减1是因为to_categorical从0开始索引

# %%
y_pred = model.predict(X)
y_pred_s = y_pred[0].flatten()
y_pred_s = np.round(y_pred_s)
y_true_s = y_spin.flatten()
spin_acc = accuracy_score(y_true_s, y_pred_s)
print('Spin Accuracy:', spin_acc)
y_pred_w = y_pred[1]
# save the y_pred_w, y_true_w to a excel file

df = pd.DataFrame({'y_pred_w': y_pred_w.flatten()})
df.to_excel('wavelength_prediction.xlsx', index=False)
df = pd.DataFrame({'y_true_w': y_true_w})
df.to_excel('wavelength_true.xlsx', index=False)


y_pred_w = np.argmax(y_pred_w, axis=1) 
y_true_w = np.argmax(y_wavelength, axis=1) 
wavelength_acc = accuracy_score(y_true_w, y_pred_w)
print('Wavelength Accuracy:', wavelength_acc)
# Out:
# 1/1 [==============================] - 0s 12ms/step
# Spin Accuracy: 1.0
# Wavelength Accuracy: 0.875

# %%
# draw the confusion matrix of spin and wavelength



fig = plt.figure(figsize=(6, 4))
confusion = confusion_matrix(y_true_s, y_pred_s)
sns.heatmap(confusion, annot=True, fmt='d', cmap='Reds', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Spin', fontsize=14)
plt.ylabel('True Spin', fontsize=14)
plt.xticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.yticks([0.5, 1.5], ['Left', 'Right'], fontsize=12)
plt.show()

# %%
# all_calss = np.arange(1, 8)
print(y_true_w)
print(y_pred_w)

all_classes = np.arange(0,14 )  # 从1到7的类别

# 生成混淆矩阵，明确指定类别标签
confusion = confusion_matrix(y_true_w, y_pred_w, labels=all_classes)

# 绘制热图
fig = plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Reds', square=True, annot_kws={"size": 14})
plt.xlabel('Predicted Wavelength (m)', fontsize=14)
plt.ylabel('True Wavelength (m)', fontsize=14)
plt.xticks(np.arange(len(all_classes)) + 0.5, all_classes, fontsize=12)  # 设置x轴标签
plt.yticks(np.arange(len(all_classes)) + 0.5, all_classes, fontsize=12)  # 设置y轴标签
plt.title('Confusion Matrix')
plt.show()
# Out:
# [ 1  1  3  3  6  6 12 12]
# [ 1  1  3  3  6  6 11 12]
